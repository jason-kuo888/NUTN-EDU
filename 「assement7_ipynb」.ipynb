# %% [markdown]
# <a href="https://colab.research.google.com/github/jason-kuo888/NUTN-EDU/blob/master/%E3%80%8Cassement7_ipynb%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("reader")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(reader)
library(ggplot2)

# %%
universitydataset <- read.csv("108_staff.csv")

# %%
head(universitydataset)
# Out:
#   學校代碼 學校名稱         職員男 職員女 秘書男 秘書女 教務男 教務女 學務男
# 1 1        國立政治大學     169     478   0       8      2      8      5
# 2 2        國立清華大學     187     542   1      22      1     40     25
# 3 3        國立臺灣大學     484    1115   2      42     20     63     42
# 4 4        國立臺灣師範大學 193     568   5      29      6     43     21
# 5 5        國立成功大學     135     349   5      20      6     25      6
# 6 6        國立中興大學     155     431   5      19      6     37     18
#   學務女 ⋯ 助教男 助教女 其他男 其他女 警衛男 警衛女 工友男 工友女 縣市名稱
# 1 11     ⋯   7     38    129    330    11     0       35    20     30臺北市
# 2 56     ⋯   0      0     50    169    19     1       38    20     18新竹市
# 3 70     ⋯ 207    428     61    130    21     0      103    72     30臺北市
# 4 52     ⋯  30    131     31    104    18     1       28    49     30臺北市
# 5 12     ⋯   3     10     47    138    18     0       50    50     21臺南市
# 6 40     ⋯  42    153     22     39    13     0       29    36     19臺中市
#   體系別
# 1 1一般
# 2 1一般
# 3 1一般
# 4 3師範
# ...

# %%
ggplot(universitydataset,aes(x=學校名稱	 , y=秘書男))+geom_point()
# Out:
# plot without title

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable=TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
ggplot(universitydataset,aes(x=學務男	))+geom_bar()
# Out:
# plot without title

# %%
ggplot(universitydataset,aes(x=學校名稱	 , y=秘書男))+geom_point()
# Out:
# plot without title

# %%
qplot(職員女,職員男,data=universitydataset,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(x=學校名稱 , y=秘書男, data=universitydataset, color=秘書男)
# Out:
# plot without title

# %%
qplot(縣市名稱,data=universitydataset,fill=職員男)
# Out:
# plot without title

# %%
ggplot(universitydataset,aes(x=職員女 , y=職員男	 ))+geom_polygon()
# Out:
# plot without title
