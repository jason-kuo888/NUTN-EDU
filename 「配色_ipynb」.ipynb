# %% [markdown]
# <a href="https://colab.research.google.com/github/jason-kuo888/NUTN-EDU/blob/master/%E3%80%8C%E9%85%8D%E8%89%B2_ipynb%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
devtools::install_github('cttobin/ggthemr')
# Out:
# ...
# vctrs      (0.3.4 -> 0.3.5) [CRAN]
# pillar     (1.4.6 -> 1.4.7) [CRAN]
# magrittr   (1.5   -> 2.0.1) [CRAN]
# cli        (2.1.0 -> 2.2.0) [CRAN]
# rstudioapi (0.12  -> 0.13 ) [CRAN]
# rprojroot  (1.3-2 -> 2.0.2) [CRAN]
# Installing 6 packages: vctrs, pillar, magrittr, cli, rstudioapi, rprojroot
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ✔  checking for file ‘/tmp/RtmpC4ch0a/remotes3b11361ad7/Mikata-Project-ggthemr-3a86e28/DESCRIPTION’
# ─  preparing ‘ggthemr’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Removed empty directory ‘ggthemr/README_files’
# ─  building ‘ggthemr_1.1.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggthemr)

# %%
ggthemr("grass")

# %%
install.packages("SportsAnalytics")    
library("SportsAnalytics")             
NBA1819<-fetch_NBAPlayerStatistics("18-19")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("ggplot2") #安裝ggplot2
library(ggplot2)      #讀取ggplot2
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
qplot(ThreesMade, TotalPoints, data = NBA1819,
geom = c("point", "smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalPoints, data=NBA1819,
   facets=Position ~ . , biwidth=10)
# Out:
# Warning message:
# “Ignoring unknown parameters: biwidth”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
df<-data.frame(gp=factor(rep(letters[1:3],each=10)),y=rnorm(30))
ggplot(df,aes(x=gp,y=y))+geom_point()
# Out:
# plot without title

# %%
ggplot(df,aes(x=gp,y=y))+geom_boxplot()
# Out:
# plot without title

# %%
NBA1819<-fetch_NBAPlayerStatistics("18-19") 
qplot(FieldGoalsAttempted, TotalPoints, data=NBA1819)
# Out:
# plot without title
